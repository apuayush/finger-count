# %% [markdown]
# 1- Getting the Image Data

# %%
# Important image loading libraries
from cv2 import *
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def load_image(path):
    c=1
    all_data = os.listdir(path)
    X = []
    Y = []
    for gesture in all_data:
        g_path = os.path.join(path,gesture)
        for image in os.listdir(g_path):
            img_path = os.path.join(g_path, image)
            img = cv2.imread(img_path)
#             img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
            img = cv2.resize(img, (64, 64), interpolation = cv2.INTER_NEAREST)
            if c%50 == 0:
                plt.figure()
                plt.imshow(img)
            c+=1
            X.append(img)
            Y.append(gesture)
            
    X = np.array(X)/255
    return X, Y

# %%
X_orig, Y_orig = load_image("/home/apurvnit/datasets/pickandplace/test")

# %%
# importing tensorflow 
import tensorflow as tf

# %%
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder


label = LabelEncoder().fit_transform(Y_orig)
res = tf.one_hot(indices=label, depth=2)

# %%
print(X_train.shape, X_val.shape, Y_train.shape)
# Out:
# (356, 64, 64, 3) (89, 64, 64, 3) (356,)

# %%
print(Y_temp.shape)
# Out:
# (1, 445)

# %%
def Network(X_train, Y_train):
    X = tf.placeholder(tf.float32, shape = (X_train.shape[0], 64, 64, 3))
    Y = tf.placeholder(tf.float32, shape = (X_train.shape[0], 2))
    print(X,Y)
    
    W1 = tf.get_variable("W11", [4, 4, 3, 8], initializer = tf.contrib.layers.xavier_initializer())
    W2 = tf.get_variable("W22", [2, 2, 8, 16],initializer = tf.contrib.layers.xavier_initializer())
    print(W1, W2)
#     tf.reset_default_graph()
    with tf.Session() as sess_test:
        init = tf.global_variables_initializer()
        sess_test.run(init)
        print("W1 = " + str(W1.eval()[1,1,1]))
        print("W2 = " + str(W2.eval()[1,1,1]))

# %%
Network(X_orig, label)
# Out:
# Tensor("Placeholder_10:0", shape=(445, 64, 64, 3), dtype=float32) Tensor("Placeholder_11:0", shape=(445, 2), dtype=float32)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b28a339f485b> in <module>()
# ----> 1 Network(X_orig, label)
#
# <ipython-input-31-f86751b874da> in Network(X_train, Y_train)
#       6     W11 = tf.get_variable("W11", [4, 4, 3, 8], initializer = tf.contrib.layers.xavier_initializer())
#       7     W22 = tf.get_variable("W22", [2, 2, 8, 16],initializer = tf.contrib.layers.xavier_initializer())
# ----> 8     print(W1, W2)
#       9 #     tf.reset_default_graph()
#      10     with tf.Session() as sess_test:
#
# NameError: name 'W1' is not defined
